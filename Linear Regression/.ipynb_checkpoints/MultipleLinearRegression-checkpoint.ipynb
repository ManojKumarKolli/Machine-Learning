# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.drop(columns=['id', 'date'], inplace=True)

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
corr_mat = df.corr()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corr_mat, annot=True)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_model.score(X_train, y_train)
# Out:
# 0.7008520669016369

# %%
lr_model.score(X_test, y_test)
# Out:
# 0.696615993724039

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
# removing the outliers
bedrooms_max_thresould = df['bedrooms'].quantile(0.9999)
bedrooms_min_thresould = df['bedrooms'].quantile(0.001)

# %%
df = df[(df['bedrooms'] < bedrooms_max_thresould) & (df['bedrooms'] > bedrooms_min_thresould)]

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.139600e+04  21396.000000  21396.000000  21396.000000  2.139600e+04
# mean   5.421935e+05      3.392270      2.125082   2090.993317  1.509229e+04
# std    3.679377e+05      0.874202      0.765135    914.232963  4.136385e+04
# min    7.800000e+04      2.000000      0.500000    440.000000  5.200000e+02
# 25%    3.249500e+05      3.000000      1.750000   1440.000000  5.060000e+03
# 50%    4.514275e+05      3.000000      2.250000   1920.000000  7.625000e+03
# 75%    6.476250e+05      4.000000      2.500000   2557.750000  1.070225e+04
# max    7.700000e+06      9.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21396.000000  21396.000000  21396.000000  21396.000000  21396.000000
# mean       1.497196      0.007385      0.234109      3.411011      7.671995
# ...

# %%
sqft_max_thresould = df['sqft_living'].quantile(0.9995)
sqft_min_thresould = df['sqft_living'].quantile(0.0005)

sqft_max_thresould
# Out:
# 7859.075000000048

# %%
df = df[df['sqft_living'] < sqft_max_thresould]

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.138500e+04  21385.000000  21385.000000  21385.000000  2.138500e+04
# mean   5.399833e+05      3.391256      2.122983   2087.161702  1.507051e+04
# std    3.524543e+05      0.873161      0.759201    897.850384  4.132331e+04
# min    7.800000e+04      2.000000      0.500000    440.000000  5.200000e+02
# 25%    3.249500e+05      3.000000      1.750000   1440.000000  5.060000e+03
# 50%    4.510000e+05      3.000000      2.250000   1920.000000  7.620000e+03
# 75%    6.460000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    5.300000e+06      9.000000      7.500000   7850.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21385.000000  21385.000000  21385.000000  21385.000000  21385.000000
# mean       1.496914      0.007248      0.232780      3.411176      7.669628
# ...

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_out_model = LinearRegression()
lr_out_model.fit(X_train, y_train)
lr_out_model.score(X_test, y_test)
# Out:
# 0.6961627237199111
